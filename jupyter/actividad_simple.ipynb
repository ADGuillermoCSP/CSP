# %% [markdown]
# # Actividad simple en Jupyter Notebook

# %%
segundos = 3670
horas = segundos // 3600
minutos = (segundos % 3600) // 60
segundos_restantes = segundos % 60

print(f"{segundos} segundos equivalen a {horas}h {minutos}m {segundos_restantes}s")
# Out:
# 3670 segundos equivalen a 1h 1m 10s
